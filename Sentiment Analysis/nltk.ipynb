# %%
#Vectorizing documents using NLTK

text = "I am not a sentimental person but I believe in the utility of sentiment analysis"

# %%
# Tokenization
from nltk.tokenize import word_tokenize
import nltk
#nltk.download('punkt')
#nltk.download('wordnet')
#nltk.download('all')

# %%
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['I', 'am', 'not', 'a', 'sentimental', 'person', 'but', 'I', 'believe', 'in', 'the', 'utility', 'of', 'sentiment', 'analysis']

# %%
# Lemmatization
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
tokens=[lemmatizer.lemmatize(word) for word in tokens]

# %%
tokens
# Out:
# ['I',
#  'am',
#  'not',
#  'a',
#  'sentimental',
#  'person',
#  'but',
#  'I',
#  'believe',
#  'in',
#  'the',
#  'utility',
#  'of',
#  'sentiment',
#  'analysis']

# %%
# Stemming
from nltk.stem import PorterStemmer
tokens=word_tokenize(text.lower())
ps = PorterStemmer()
tokens=[ps.stem(word) for word in tokens]
print(tokens)
# Out:
# ['i', 'am', 'not', 'a', 'sentiment', 'person', 'but', 'i', 'believ', 'in', 'the', 'util', 'of', 'sentiment', 'analysi']

# %%
# Stop words
import nltk
stopwords = nltk.corpus.stopwords.words('english')
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
tokens_new = [j for j in tokens if j not in stopwords]

# %%
tokens_new
# Out:
# ['sentiment', 'person', 'believ', 'util', 'sentiment', 'analysi']

# %%
################################Vader Demo#####################################

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyser = SentimentIntensityAnalyzer()
#analyser.polarity_scores("This is a good course")
analyser.polarity_scores("This is an awesome course") # degree modifier
# analyser.polarity_scores("The instructor is so cool")
# analyser.polarity_scores("The instructor is so cool!!") # exclaimataion changes score
# analyser.polarity_scores("The instructor is so COOL!!") # Capitalization changes score
# analyser.polarity_scores("Machine learning makes me :)") #emoticons
# analyser.polarity_scores("His antics had me ROFL")
# analyser.polarity_scores("The movie SUX") #Slangs
# Out:
# {'neg': 0.0, 'neu': 0.494, 'pos': 0.506, 'compound': 0.6249}

# %%
################################Textblob Demo##################################

from textblob import TextBlob

# TextBlob("His").sentiment
# TextBlob("remarkable").sentiment
# TextBlob("work").sentiment
# TextBlob("ethic").sentiment
# TextBlob("impressed").sentiment
# TextBlob("me").sentiment
TextBlob("His remarkable work ethic impressed me").sentiment
# Out:
# Sentiment(polarity=0.875, subjectivity=0.875)

# %%
# import necessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# Create lists to store scraped news urls, headlines and text
url_list = []
date_time = []
news_text = []
headlines = []

# %%
for i in range(1,3): #parameters of range function correspond to page numbers in the website with news listings
    #get the list of unique urls in the page
    url = 'https://oilprice.com/Energy/Crude-Oil/Page-{}.html'.format(i)
    request = requests.get(url)
    soup = BeautifulSoup(request.text, "html.parser")
    for links in soup.find_all('div', {'class': 'categoryArticle'}):
        for info in links.find_all('a'):
            if info.get('href') not in url_list:
                url_list.append(info.get('href'))

# %%
for www in url_list:
    #access each url
    headlines.append(www.split("/")[-1].replace('-',' '))
    request = requests.get(www)
    soup = BeautifulSoup(request.text, "html.parser")
    
    #store date and time of publication of the article
    for dates in soup.find_all('span', {'class': 'article_byline'}):
        date_time.append(dates.text.split('-')[-1])
    
    #store the text of the news
    temp = []
    for news in soup.find_all('p'):
            temp.append(news.text)
    
    #identify the last line of the news article
    for last_sentence in reversed(temp):
        if last_sentence.split(" ")[0]=="By" and last_sentence.split(" ")[-1]=="Oilprice.com":
            break
        elif last_sentence.split(" ")[0]=="By":
            break
    
    #prune non news related text from the scraped data to create the news text
    joined_text = ' '.join(temp[temp.index("More Info")+1:temp.index(last_sentence)])
    news_text.append(joined_text)

# %%
# save news text along with the news headline in a dataframe      
news_df = pd.DataFrame({ 'Date' : date_time,
                         'Headline': headlines,
                         'News': news_text,
                       })

# %%
# use VADER to perform sentiment analysis on stored news articles
analyser = SentimentIntensityAnalyzer()

def comp_score(text):
   return analyser.polarity_scores(text)["compound"]   
  
news_df["sentiment"] = news_df["News"].apply(comp_score)

# %%
news_df
# Out:
#                            Date  \
# 0     Aug 01, 2022, 6:00 PM CDT
# 1    Aug 01, 2022, 10:30 AM CDT
# 2     Jul 29, 2022, 2:00 PM CDT
# 3     Jul 31, 2022, 6:00 PM CDT
# 4     Jul 31, 2022, 2:00 PM CDT
# 5     Jul 30, 2022, 4:00 PM CDT
# 6    Jul 29, 2022, 10:00 AM CDT
# 7     Jul 28, 2022, 7:00 PM CDT
# 8    Jul 28, 2022, 10:30 AM CDT
# 9    Jul 28, 2022, 11:00 AM CDT
# 10    Jul 27, 2022, 7:00 PM CDT
# 11   Jul 27, 2022, 11:00 AM CDT
# 12    Jul 27, 2022, 5:00 PM CDT
# 13    Jul 27, 2022, 4:00 PM CDT
# 14    Jul 26, 2022, 7:00 PM CDT
# 15   Jul 26, 2022, 11:00 AM CDT
# 16    Jul 26, 2022, 4:00 PM CDT
# 17    Jul 25, 2022, 7:00 PM CDT
# 18    Jul 25, 2022, 3:00 PM CDT
# 19   Jul 25, 2022, 10:00 AM CDT
# 20    Jul 25, 2022, 8:30 AM CDT
# 21   Jul 22, 2022, 12:15 PM CDT
# 22    Jul 24, 2022, 6:00 PM CDT
# 23    Jul 24, 2022, 2:00 PM CDT
# 24   Jul 22, 2022, 11:00 AM CDT
# 25    Jul 21, 2022, 5:00 PM CDT
# 26    Jul 21, 2022, 6:00 PM CDT
# 27   Jul 20, 2022, 12:00 PM CDT
# 28   Jul 20, 2022, 11:00 AM CDT
# 29    Jul 19, 2022, 7:00 PM CDT
# 30    Jul 19, 2022, 4:00 PM CDT
# 31   Jul 19, 2022, 10:15 AM CDT
# 32   Jul 19, 2022, 12:00 PM CDT
# 33    Jul 19, 2022, 8:00 AM CDT
# 34    Jul 18, 2022, 6:00 PM CDT
# 35   Jul 18, 2022, 11:00 AM CDT
# 36   Jul 18, 2022, 10:00 AM CDT
# 37    Jul 18, 2022, 9:00 AM CDT
# 38    Jul 18, 2022, 7:45 AM CDT
# 39    Jul 16, 2022, 6:00 PM CDT
#
#                                              Headline  \
# 0   How Russian Oil Is Making Its Way From Europe ...
# 1          Oil Dips Amid Renewed Demand Concerns.html
# 2               US Crude Production Sinks In May.html
# 3   Demand Destruction Could Help America Refill I...
# 4   NOCs Not Big Oil Are Responsible For Most Emis...
# 5   More Oil Discoveries Boost Guyanas Offshore Bo...
# 6   US Refiners Havent Seen Fuel Demand Destructio...
# 7   Big Oil Set For Blowout Performance But What C...
# 8   Shell And TotalEnergies See Risk Of Higher Oil...
# 9   Earnings Season Is Here And Energy Companies A...
# 10  Saudi Arabias Real Production Capacity Is 15 M...
# 11   G7 Presses Ahead With Russian Oil Price Cap.html
# 12     Irans Oil Earnings Soar Despite Sanctions.html
# 13  US Remains Worlds Top Oil Producer And Consume...
# 14  High Oil Prices Spark A New Wave Of Exploratio...
# 15  Libya Raises Oil Production To 11 Million Bpd....
# 16  East African Governments Clash With Environmen...
# 17  Traders Are Betting On The End Of The Oil Pric...
# 18  Gulf Producers Hike Crude Prices Despite Reces...
# 19   Will Russia Cut Natural Gas Flows To Europe.html
# 20          US SPR Releases Set To End This Fall.html
# 21  US Oil Rig Count Unchanged As WTI Slumps Below...
# 22            High Crude Prices Are Here To Stay.html
# 23  Guyana Poised To Break 1 Billion In Oil And Ga...
# 24  Worlds Top Oilfield Service Provider Raises Ea...
# 25  Putin Calls Saudi Crown Prince To Discuss Oil ...
# 26  The Middle East Oil Bonanza Will Slow In 2023....
# 27  Saudi Arabias Ability To Pump More Oil Limited...
# 28  Russias Cheap Oil Gains Market Share In China....
# 29  How China Could Trigger The Next Sharp Selloff...
# 30            Libyas Oil Crisis Is Far From Over.html
# 31  Libya To Resume Oil Exports After Lifting Forc...
# 32  Are OPEC And The IEA Right About Whats Next Fo...
# 33   Keystone Force Majeure Cuts Oil Flows To US.html
# 34  Tanker Companies Race To Ship Russian Oil Ahea...
# 35                    Chinas Fuel Exports Plunge.html
# 36  Biden Advisor Sees OPEC Raising Oil Production...
# 37  Saudi Arabia Reveals Oil Production Capacity L...
# 38  Biden Fails To Secure Firm Pledge From Saudis ...
# 39  Is This The Only Way To Curb Russian Oil Reven...
#
#                                                  News  sentiment
# 0   Russia has been ramping up oil exports to Asia...     0.9095
# 1   Oil prices plunged by 4% at the start of Augus...    -0.9477
# 2   U.S. field production of crude oil fell in May...    -0.8930
# 3   U.S. petroleum inventories are still sitting a...    -0.9682
# 4                                                         0.0000
# 5   The former British colony of Guyana, a nation ...    -0.9870
# 6   U.S. refiners say there is no indication acros...    -0.9306
# 7   Earnings season is here with us once again, wi...     0.9971
# 8   As oil companies begin to report their impress...    -0.7773
# 9   Much to the chagrin of snowflakes everywhere, ...     0.9842
# 10  As the OPEC+ group prepares to roll back all p...     0.9896
# 11  The G7 are pressing on with their price cap on...    -0.4255
# 12  Iran’s oil industry seems to be going from str...     0.9954
# 13  Earlier this month BP released its Statistical...     0.9545
# 14  When the energy crisis hit a nadir two years a...     0.9936
# 15  Libya, plagued by port blockades and protests ...    -0.8402
# 16  East Africa seems to be split in favour of and...     0.9926
# 17                                                        0.0000
# 18  In hindsight, June 2022 might go down as the l...    -0.3994
# 19  Despite the fact that Nord Stream last week re...    -0.7794
# 20  The record-high release of crude oil from the ...     0.6164
# 21  The number of total active drilling rigs in th...    -0.6249
# 22  Crude oil has been on a decline over the past ...     0.9399
# 23  As the burgeoning Guyanese offshore oil and ga...     0.9979
# 24  Schlumberger (NYSE: SLB) reported on Friday hi...     0.9894
# 25  Russian President Vladimir Putin had a phone c...     0.9426
# 26  Slowing global oil demand growth next year, sp...     0.9847
# 27  Saudi Arabia has limited additional crude oil ...    -0.5719
# 28  China continues to buy discounted Russian crud...    -0.9628
# 29                                                        0.0000
# 30    For a moment last week, it seemed that Libya...     0.8820
# 31  Libya will begin loading oil for export on Jul...    -0.7717
# 32  Both OPEC and the International Energy Agency ...    -0.9534
# 33  TC Energy, the operator of the Keystone Pipeli...    -0.9209
# 34  Western sanctions have so far failed to crush ...    -0.6661
# 35  China’s exports of gasoline and diesel slumped...    -0.7885
# 36  The United States believes that OPEC’s Middle ...     0.9885
# 37  Saudi Arabia, the world’s top crude oil export...     0.9642
# 38  U.S. President Joe Biden returned to Washingto...     0.9926
# 39  The West is looking to cap the price of Russia...    -0.9926
